# %% [markdown]
# # 归一化 && Pandas怎样对每个分组应用apply函数?

# %% [markdown]
# **知识：Pandas的GroupBy遵从split、apply、combine模式**
#
# ![img](https://nbviewer.jupyter.org/github/peiss/ant-learn-pandas/blob/master/other_files/pandas-split-apply-combine.png)
#
# 这里的split指的是pandas的groupby，我们自己实现apply函数，apply返回的结果由pandas进行combine得到结果
#
# **GroupBy.apply(function)**
#
# - function的第一个参数是dataframe
# - function的返回结果，可是dataframe、series、单个值，甚至和输入dataframe完全没关系
#
# **本次实例演示：**
#
# 1. 怎样对数值列按分组的归一化？
# 2. 怎样取每个分组的TOPN数据？

# %% [markdown]
# ## 实例1：怎样对数值列按分组的归一化？
#
# 将不同范围的数值列进行归一化，映射到[0,1]区间：
#
# - 更容易做数据横向对比，比如价格字段是几百到几千，增幅字段是0到100
# - 机器学习模型学的更快性能更好
#
# ### 线性函数的归一化的公式：
#
# ![img](https://nbviewer.jupyter.org/github/peiss/ant-learn-pandas/blob/master/other_files/Normalization-Formula.jpg)
#
# ### 演示：最高温，最低温，空气指数aqi 归一化

# %%
# 处理温差
df['diff'] = df['max_temperature'] - df['min_temperature']

# %%
df.head()
# Out:
#                   date week  max_temperature  min_temperature day_status  \
# date
# 2017-01-01  2017-01-01   周日              9.0              2.0         多云
# 2017-01-02  2017-01-02   周一              9.0              2.0          霾
# 2017-01-03  2017-01-03   周二              9.0              2.0        霾~雾
# 2017-01-04  2017-01-04   周三              9.0              2.0         小雨
# 2017-01-05  2017-01-05   周四              5.0              1.0         小雨
#
#                wind  aqi aqi_status 中文月份1 中文月份2 中文月份3 中文月份4  diff
# date
# 2017-01-01  无持续风向微风  372         严重    一月    一月    一月    一月   7.0
# 2017-01-02  无持续风向微风  361         严重    一月    一月    一月    一月   7.0
# 2017-01-03  无持续风向微风  280         重度    一月    一月    一月    一月   7.0
# 2017-01-04  无持续风向微风  193         中度    一月    一月    一月    一月   7.0
# 2017-01-05  无持续风向微风  216         重度    一月    一月    一月    一月   4.0

# %%
# 检查异常值
print(df['max_temperature'].max())
print(df['min_temperature'].max())
print(df['aqi'].max())
# Out:
# 39.0
# 29.0
# 422

# %%
# 方法1
df['max1'] = (df['max_temperature'] - df['max_temperature'].min()) / \
    (df['max_temperature'].max() - df['max_temperature'].min())
df['max1'].head()
# Out:
# date
# 2017-01-01    0.268293
# 2017-01-02    0.268293
# 2017-01-03    0.268293
# 2017-01-04    0.268293
# 2017-01-05    0.170732
# Name: max1, dtype: float64

# %%
df['max_temperature'].map(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in double_scalars
#   """Entry point for launching an IPython kernel.
# date
# 2017-01-01   NaN
# 2017-01-02   NaN
# 2017-01-03   NaN
# 2017-01-04   NaN
# 2017-01-05   NaN
#               ..
# 2019-12-27   NaN
# 2019-12-28   NaN
# 2019-12-29   NaN
# 2019-12-30   NaN
# 2019-12-31   NaN
# Name: max_temperature, Length: 1095, dtype: float64

# %%
df['max1'] = df[['max_temperature']].apply(
    lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
df['max1'].head()
# Out:
# date
# 2017-01-01    0.268293
# 2017-01-02    0.268293
# 2017-01-03    0.268293
# 2017-01-04    0.268293
# 2017-01-05    0.170732
# Name: max1, dtype: float64

# %%
type(df['max_temperature'])
# Out:
# pandas.core.series.Series

# %%
type(df[['max_temperature']])
# Out:
# pandas.core.frame.DataFrame

# %%
# min
# aqi
# diff
df['min1'] = df[['min_temperature']].apply(
    lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
df['aqi1'] = df[['aqi']].apply(lambda x: (
    x - np.min(x)) / (np.max(x) - np.min(x)))
df['diff1'] = df[['diff']].apply(lambda x: (
    x - np.min(x)) / (np.max(x) - np.min(x)))

# %%
df.cov()
# Out:
#                  max_temperature  min_temperature          aqi       diff  \
# max_temperature       110.751668       101.611776  -243.277537   9.139892
# min_temperature       101.611776       102.135375  -273.362354  -0.523599
# aqi                  -243.277537      -273.362354  3624.097009  30.084817
# diff                    9.139892        -0.523599    30.084817   9.663491
# max1                    2.701260         2.478336    -5.933598   0.222924
# min1                    2.605430         2.618856    -7.009291  -0.013426
# aqi1                   -0.605168        -0.680006     9.015167   0.074838
# diff1                   0.507772        -0.029089     1.671379   0.536861
#
#                      max1      min1      aqi1     diff1
# max_temperature  2.701260  2.605430 -0.605168  0.507772
# min_temperature  2.478336  2.618856 -0.680006 -0.029089
# aqi             -5.933598 -7.009291  9.015167  1.671379
# diff             0.222924 -0.013426  0.074838  0.536861
# max1             0.065884  0.063547 -0.014760  0.012385
# min1             0.063547  0.067150 -0.017436 -0.000746
# aqi1            -0.014760 -0.017436  0.022426  0.004158
# diff1            0.012385 -0.000746  0.004158  0.029826

# %%
df.corr()
# Out:
#                  max_temperature  min_temperature       aqi      diff  \
# max_temperature         1.000000         0.955390 -0.383996  0.279382
# min_temperature         0.955390         1.000000 -0.449315 -0.016666
# aqi                    -0.383996        -0.449315  1.000000  0.160761
# diff                    0.279382        -0.016666  0.160761  1.000000
# max1                    1.000000         0.955390 -0.383996  0.279382
# min1                    0.955390         1.000000 -0.449315 -0.016666
# aqi1                   -0.383996        -0.449315  1.000000  0.160761
# diff1                   0.279382        -0.016666  0.160761  1.000000
#
#                      max1      min1      aqi1     diff1
# max_temperature  1.000000  0.955390 -0.383996  0.279382
# min_temperature  0.955390  1.000000 -0.449315 -0.016666
# aqi             -0.383996 -0.449315  1.000000  0.160761
# diff             0.279382 -0.016666  0.160761  1.000000
# max1             1.000000  0.955390 -0.383996  0.279382
# min1             0.955390  1.000000 -0.449315 -0.016666
# aqi1            -0.383996 -0.449315  1.000000  0.160761
# diff1            0.279382 -0.016666  0.160761  1.000000

# %% [markdown]
# ### Z-score标准化方法
#
#    这种方法给予原始数据的均值（mean）和标准差（standard deviation）进行数据的标准化。经过处理的数据符合标准正态分布，即均值为0，标准差为1，转化函数为：
#    $$
#    \hat x=\frac{x-\mu}{\sigma}
#    $$
#    其中为μ所有样本数据的均值，σ为所有样本数据的标准差。该种归一化方式要求原始数据的分布可以近似为高斯分布，否则处理的效果会变差。
#
# ![image.png](attachment:image.png)

# %%
# 样本标准差和总体标准差 https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html
# ddof  int, default 1
# N - ddof

# %%
# df.std(ddof=1)
# 样本标准差
df['max_temperature'].std(ddof=1)
# Out:
# 10.523861852688613

# %%
# 总体标准差
df['max_temperature'].std(ddof=0)
# Out:
# 10.51905533868924
